# %% [markdown]
# ## Import python modules

# %%
import re # regular expressions: working with string 
import pandas as pd # working with dataset
import enchant # dictionary
d = enchant.Dict("en_US")

# %%
# test dictionary module
d.check('N?oriental')
# Out:
# False

# %% [markdown]
# ### Import manually created files

# %%
remove_words_file = open('remove_words.csv').read()
remove_words = ['\\b' + w.lower() + '\\b' for 
                w in re.split('\n',remove_words_file) if not w=='']

# %% [markdown]
# ### Define auxiliary functions

# %%
def reset_space(input_string):
    # This function removes unnecessary white spaces.
    string_reset_space = [w for w in re.split(' ',input_string) 
                          if not w=='']
    return ' '.join(string_reset_space)

def initial_clean(input_string):
    # This function performs initial cleaning steps.
    # (1.) convert to lowercase
    clean = input_string.lower()
    
    # (2.) remove abbrevations (any word or letter followed by a period, ".")
    clean = re.sub(r'\w+\.','', clean)
    clean = reset_space(clean)
    
    # (3.) remove characters in parentheses (remove also the parentheses)
    clean = re.sub(re.escape('(') + '[a-z0-9 ]+' + re.escape(')'),' ',clean)
    clean = reset_space(clean)
    
    # (4.) replace ",", ".", ":", ";", "/", "?" and "!" with a whitespace, " "
    remove_character = [',', '.', ':', ';', '/', '?', '!']
    for i in remove_character:
        clean = clean.replace(i,' ')
    clean = reset_space(clean)
        
    # (5.) change "it" to "information technology"
    clean = re.sub(r'\bit\b', ' information technology ', clean)
    clean = reset_space(clean)
    
    # (6.) remove numbers and ordinal number suffix, ie., "1st", "2nd"
    clean = re.sub(r'\b1st|2nd|3rd|\d+th\b', ' ', clean)
    clean = re.sub(r'\d+', ' ', clean)
    clean = reset_space(clean)
    
    # (7.) remove words in "remove_words.csv"
    clean = re.sub('|'.join(remove_words),' ',clean)
    clean = reset_space(clean)
    
    return clean

def detect_non_ascii(text):
    # This function detects non-ASCII characters. 
    output = False
    if max([ord(w) for w in str(text)]) >= 127:
        output = True
    return output

def count_word(text):
    # This function count words.
    alphabets = re.sub('[^a-z]',' ',text.lower())
    tokens = [w for w in re.split(' ',alphabets) if not w=='']
    return len(tokens)

def detect_strange_text(text):
    # This function detect strange text
    alphabets = re.sub('[^a-z]',' ',text.lower())
    tokens = [w for w in re.split(' ',alphabets) if not w=='']
    
    output = False
    for word in tokens:
        if not d.check(word):
            output = True

    return output

# %% [markdown]
# ### Import education entries

# %%
data_filename = 'educ_danish.csv'

data = pd.read_csv(data_filename,
                   sep = ',',
                   encoding = 'cp865',
                   names = ['code','text'],
                   header=0, 
                   dtype = object)

# Note: encoding = 'cp865' is for Danish and Norwegian. 
print('total rows = ' + str(len(data)))
data.head() #print example
# Out:
# total rows = 2449
#   code                       text
# 0  320        Pedagogy, ivu (eud)
# 1  339  Trade / office, ivu (eud)
# 2  353    Construction, ivu (eud)
# 3  354    Iron / metal, ivu (eud)
# 4  355         Graphic, ivu (eud)

# %% [markdown]
# ###  Preprocess text (see "initial_clean" function)
# 1. convert to lowercase
# 2. remove abbrevations (any word or letter followed by a period, ".")
# 3. remove any words or letters in parentheses (remove also the parentheses)
# 4. replace ",", ".", ":", ";", "/", "?" and "!" with a whitespace, " "
# 5. change "it" to "information technology"
# 6. remove numbers and ordinal number suffix, ie., "1st", "2nd"
# 7. remove words in "remove_words.csv"

# %%
# an example
initial_clean('IT 1st instructor (test) v.o.v. PhD')
# Out:
# 'information technology instructor'

# %%
# preprocess text: create a new column called 'clean_text'
data['clean_text'] = data['text'].apply(lambda x: initial_clean(x))
data.head()
# Out:
#   code                       text    clean_text
# 0  320        Pedagogy, ivu (eud)      pedagogy
# 1  339  Trade / office, ivu (eud)  trade office
# 2  353    Construction, ivu (eud)  construction
# 3  354    Iron / metal, ivu (eud)    iron metal
# 4  355         Graphic, ivu (eud)       graphic

# %%
# some education entries become empty after initial cleaning steps 
data[data['clean_text'] == '']
# Out:
#       code                                           text clean_text
# 42     700                   Bachelor una, ivu (bachelor)
# 51     720                           Ph.D. una, ivu (PhD)
# 722   4722                       Vejgodstransportudd. una
# 1284  5680                                        MA. una
# 1332  5745                    Education, Licensing. (DPU)
# 1333  5746                  Education, Examination. (DPU)
# 1548  6145  Education and education, superstructure (RUC)
# 1839  7003                            Education, mag.art.
# 2409  9122                                        MA. una
# 2410  9123                                 Cand.phil. una
# 2411  9124                                   Mag.art. una
# 2412  9125                                  Exam.art. una
# 2420  9224                                         HD una
# 2422  9264                                       MSc. una
# 2424  9465                                   Exam. pharm.
# 2444  9716                                        MA. una

# %% [markdown]
# ### Detect education entries containing non-ASCII characters

# %%
# delete empty cleaned entries
data = data[data['clean_text'] != '']

# detect entries with non-ASCII characters
data['non_ascii'] = data['text'].apply(lambda x: detect_non_ascii(x))

# print entries with non-ASCII characters 
data_non_ascii = data[data['non_ascii']==True]
data_non_ascii.to_csv('non_ascii.csv',index=False)
data_non_ascii
# Out:
#       code                     text               clean_text  non_ascii
# 2250  8555  Media management (G├àU)  media management (g├àu)       True

# %% [markdown]
# ### Import manually corrected education entries

# %%
data_revise_filename = 'manual_correction.csv' 
data_revise = pd.read_csv(data_revise_filename,
                          sep = ',',
                          encoding = 'cp865',
                          names = ['code','text','clean_text'],
                          header = 0,
                          dtype = object)

# drop empty entries
data_revise = data_revise[~data_revise['clean_text'].isnull()]

data_revise.head()
# Out:
#    code                                               text  \
# 0  8559  Technological diploma education in bio and pro...
# 1  7746                         Danish candleholder. (DPU)
# 2  4366                                   manlift Mechanic
# 3  5401              Agricultural Economics, cand.agro.┐k.
# 4  5404              Agricultural Economics, cand.agro.┐k.
#
#                            clean_text
# 0            bioengineering chemistry
# 1                 language literature
# 2   repair troubleshoot mechanic lift
# 3              agricultural economics
# 4              agricultural economics

# %%
# create a new dataframe "replace_obs" to record entries 
# which have been manually corrected.
replace_obs = data_revise
replace_obs['replace_obs'] = True
replace_obs = replace_obs[['code','replace_obs']]
replace_obs.head()
# Out:
#    code  replace_obs
# 0  8559         True
# 1  7746         True
# 2  4366         True
# 3  5401         True
# 4  5404         True

# %%
# merge "replace_obs" to "data" 
data = data.merge(replace_obs, on = 'code', how = 'left')

# drop entries in "data" where replace_obs is True 
data = data[data['replace_obs'] != True]

# merge "data_revise" to "data"   
data = data.append(data_revise, ignore_index=True)
data = data[['code','text','clean_text']]
data
# Out:
#       code                                           text  \
# 0      320                            Pedagogy, ivu (eud)
# 1      339                      Trade / office, ivu (eud)
# 2      353                        Construction, ivu (eud)
# 3      354                        Iron / metal, ivu (eud)
# 4      355                             Graphic, ivu (eud)
# 5      358    Technology / industry by the way, ivu (eud)
# 6      360                             Service, ivu (eud)
# 7      375                    Food / household, ivu (eud)
# 8      380             Agriculture / fisheries, ivu (eud)
# 9      385                     Transport, etc., ivu (eud)
# 10     390                     Social / health, ivu (eud)
# 11     425   Communication / Business Language, ivu (kvu)
# 12     430                            Artistic, ivu (kvu)
# 13     439                           Sociology, ivu (kvu)
# 14     459                           Technical, ivu (kvu)
# 15     475                    Food / household, ivu (kvu)
# 16     480             Agriculture / fisheries, ivu (kvu)
# 17     485                     Transport, etc., ivu (kvu)
# 18     490                     Social / health, ivu (kvu)
# 19     495                    Defense / police, ivu (kvu)
# 20     520                            Pedagogy, ivu (mvu)
# 21     525   Communication / business language, ivu (mvu)
# 22     530                            Artistic, ivu (mvu)
# 23     539                      Social sciences ivu (mvu)
# 24     545                    Natural Sciences, ivu (mvu)
# 25     559                           Technical, ivu (mvu)
# 26     575                    Food / household, ivu (mvu)
# 27     580             Agriculture / fisheries, ivu (mvu)
# 28     585                     Transport, etc., ivu (mvu)
# 29     590                     Social / health, ivu (mvu)
# ...    ...                                            ...
# 2411  7230                        Theology, cand. Thheol.
# 2412  4358                         Frontline PC Supporter
# 2413  4357                   Frontline Radio TV Supporter
# 2414  6870                 European journalism, cand.mag.
# 2415  4722                       Vejgodstransportudd. una
# 2416  4530                                     Sailmakers
# 2417  4532                                Model stitchers
# 2418  4339                                        Gravure
# 2419  4230                                    Shipbuilder
# 2420  4855                                   Ship Snedker
# 2421  5220             Shipmaster, with 10th grade access
# 2422  5192                     Junior Officer, 2.teoridel
# 2423  5193                     Junior Officer, 3.teoridel
# 2424  8942          Globalization and integration, master
# 2425  8440                                          SENCo
# 2426  5476  Sportsmanagement (superstructure), prof.bach.
# 2427  4345                                  Stempelgrav┐r
# 2428  5889                         V.O.U., Technical Navy
# 2429  5201                                  Telecom Pupil
# 2430  9654                                   Pianostemmer
# 2431  5802      Tonmester, film and television production
# 2432  5923                       Tonemester (music) (gl.)
# 2433  7855                      Tonemester (music), bach.
# 2434  7955               Tonemester (music), cand.musicae
# 2435  4616                                      Groundman
# 2436  5809                   Visual arts, cand.art.perit.
# 2437  4527                  Stock and Terminal Disponible
# 2438  4483                                        Urmager
# 2439  4953                          Wholesale, manufaktur
# 2440  4091                                    Tr╛tekniker
#
#                                   clean_text
# 0                                   pedagogy
# 1                               trade office
# 2                               construction
# 3                                 iron metal
# 4                                    graphic
# 5                    technology industry way
# 6                                    service
# 7                             food household
# 8                      agriculture fisheries
# 9                                  transport
# 10                             social health
# 11           communication business language
# 12                                  artistic
# 13                                 sociology
# 14                                 technical
# 15                            food household
# 16                     agriculture fisheries
# 17                                 transport
# 18                             social health
# 19                            defense police
# 20                                  pedagogy
# 21           communication business language
# 22                                  artistic
# 23                           social sciences
# 24                          natural sciences
# 25                                 technical
# 26                            food household
# 27                     agriculture fisheries
# 28                                 transport
# 29                             social health
# ...                                      ...
# 2411                        religion studies
# 2412                         repair computer
# 2413                 repair radio television
# 2414           report communicate journalist
# 2415  road freight distribution construction
# 2416                             sail makers
# 2417                                   sewer
# 2418               shape engrave steel metal
# 2419                            ship builder
# 2420                          ship carpenter
# 2421                             ship master
# 2422                            ship officer
# 2423                            ship officer
# 2424                 social sciences studies
# 2425               special education teacher
# 2426                      sports management
# 2427                     stamp craft engrave
# 2428                          technical navy
# 2429                       telecommunication
# 2430                tune musical instruments
# 2431                  tuner sound technician
# 2432                  tuner sound technician
# 2433                  tuner sound technician
# 2434                  tuner sound technician
# 2435    utility repair maintain construction
# 2436                             visual arts
# 2437                          warehouse work
# 2438                             watch maker
# 2439                   wholesale manufacture
# 2440                         wood technician
#
# [2441 rows x 3 columns]

# %% [markdown]
# ### Count words in each data entry

# %%
data['count_word'] = data['clean_text'].apply(lambda x: count_word(x))
data.head(10)
# Out:
#   code                                         text               clean_text  \
# 0  320                          Pedagogy, ivu (eud)                 pedagogy
# 1  339                    Trade / office, ivu (eud)             trade office
# 2  353                      Construction, ivu (eud)             construction
# 3  354                      Iron / metal, ivu (eud)               iron metal
# 4  355                           Graphic, ivu (eud)                  graphic
# 5  358  Technology / industry by the way, ivu (eud)  technology industry way
# 6  360                           Service, ivu (eud)                  service
# 7  375                  Food / household, ivu (eud)           food household
# 8  380           Agriculture / fisheries, ivu (eud)    agriculture fisheries
# 9  385                   Transport, etc., ivu (eud)                transport
#
#    count_word
# 0           1
# 1           2
# 2           1
# 3           2
# 4           1
# 5           3
# 6           1
# 7           2
# 8           2
# 9           1

# %% [markdown]
# ### Detect entries with strange words

# %%
data['strange_text'] = data['clean_text'].apply(lambda x: detect_strange_text(x))
data.to_csv('clean_text.csv',index=False)
data[data['strange_text'] == True]
# Out:
#       code                                               text  \
# 391   4356                    Telecom Installation Technician
# 483   4478                              Film and TV assistant
# 484   4479                 Film and TV production technicians
# 655   4878                                     Bacontilvirker
# 676   4918                                retail TV and radio
# 843   5168              Healthcare professional, diploma exam
# 852   5177                                     Pharmaconomist
# 902   5236  Acoustics and Audiotechnology, Master of Scien...
# 906   5265                           Biomechanics, cand.manu.
# 1041  5451                                 Clinical dietician
# 1063  5487              TV and media organization, prof.bach.
# 1073  5511                   Business Studies, English-French
# 1074  5516                   Business Studies, English-German
# 1075  5520                   Business Studies, French-Spanish
# 1076  5521                    Business Studies, French-German
# 1077  5525                   Business Studies, Italian-German
# 1078  5531                   Business Studies, Spanish-German
# 1095  5633                  Commercial correspondent, Italian
# 1140  5733          Intercultural Market Communication, bach.
# 1178  5807  Animation instructor, film tv and interactive ...
# 1183  5816        Tv studio producer / multi-chamber director
# 1184  5817              TV organizer / documentary instructor
# 1575  7911                       Mechatronics, engineer bach.
# 1579  7916         Physics and nanotechnology, engineer bach.
# 1597  7938                     Nanotechnology, engineer bach.
# 1726  8290                     Nanotechnology, engineer bach.
# 1735  8311        Mechatronics, Master of Science cand.polyt.
# 1747  8338                     Nanotechnology, civil engineer
# 1769  8368  Physics and nanotechnology, civil engineer can...
# 1921  8905          Internet and software development, master
# 2063  4316                  Event technician, audiotechnology
# 2066  8233                       Bioinformatics, cand.scient.
# 2068  5165                                Biomechanics, bach.
# 2069  8351                                 Biosystemteknologi
# 2072  4335                          Boatbuilder and shipmaker
# 2094  4326                               Klejnsmed, rustproof
# 2110  4526                                             Nîdler
# 2118  4489                                    Farverioperat┐r
# 2119  5094      Economics economist in Eastern European trade
# 2254  4695                          Nursery Gartner Assistant
# 2263  4566                                V╛ksthusgartner una
# 2264  4615                                        Greenkeeper
# 2365  4264                               Auto electromechanic
# 2366  5439           Mekatronics, Diploma Engineer Prof.bach.
# 2368  4990                                         L?esekret?
# 2369  8555                             Media management (GüU)
# 2371  8892        Mobile Internet Communication (MIC), Master
# 2372  8295                       Nanotechnology, cand.scient.
# 2373  8291                                     Nanobioscience
# 2374  8296                                     Nanobioscience
# 2379  5156                                  ¤konomaforeningen
# 2393  4376                                Finmekanikassistent
#
#                                           clean_text  count_word  strange_text
# 391                  telecom installation technician           3          True
# 483                                film tv assistant           3          True
# 484                   film tv production technicians           4          True
# 655                                   bacontilvirker           1          True
# 676                                  retail tv radio           3          True
# 843                          healthcare professional           2          True
# 852                                   pharmaconomist           1          True
# 902                acoustics audiotechnology science           3          True
# 906                                     biomechanics           1          True
# 1041                              clinical dietician           2          True
# 1063                           tv media organization           3          True
# 1073                         business english-french           3          True
# 1074                         business english-german           3          True
# 1075                         business french-spanish           3          True
# 1076                          business french-german           3          True
# 1077                         business italian-german           3          True
# 1078                         business spanish-german           3          True
# 1095                commercial correspondent italian           3          True
# 1140              intercultural market communication           3          True
# 1178  animation instructor film tv interactive media           6          True
# 1183       tv studio producer multi-chamber director           6          True
# 1184             tv organizer documentary instructor           4          True
# 1575                           mechatronics engineer           2          True
# 1579                 physics nanotechnology engineer           3          True
# 1597                         nanotechnology engineer           2          True
# 1726                         nanotechnology engineer           2          True
# 1735                            mechatronics science           2          True
# 1747                   nanotechnology civil engineer           3          True
# 1769           physics nanotechnology civil engineer           4          True
# 1921                   internet software development           3          True
# 2063                                 audiotechnology           1          True
# 2066                                  bioinformatics           1          True
# 2068                                    biomechanics           1          True
# 2069                biosystem technology engineering           3          True
# 2072                          boat builder shipmaker           3          True
# 2094                                       claysmith           1          True
# 2110                       craftman sew shoes boots            4          True
# 2118                                 dyeing operater           2          True
# 2119                economics eastern european trade           4          True
# 2254                                         gardner           1          True
# 2263                              greenhouse gardner           2          True
# 2264                                  groundskeeping           1          True
# 2365  mechanics maintain repair cars electic service           6          True
# 2366                           mechatronics engineer           2          True
# 2368                              medical secrectary           2          True
# 2369                                meida management           2          True
# 2371        mobile internet communication technology           4          True
# 2372                                  nanotechnology           1          True
# 2373                         nanotechnology medicine           2          True
# 2374                         nanotechnology medicine           2          True
# 2379           nutition economics clinical dietician           4          True
# 2393                 precision enginnering assistant           3          True
